# %%
# This import will let us clear the Jupyter outputs
from IPython.display import clear_output

# This allows us to hide the readings from some functions
from EDL_Jupyter_resources import HiddenPrints
hiddenprints = HiddenPrints()

import random

import urllib
import webbrowser
import requests

# Import extra color sensor modules
from di_sensors.easy_light_color_sensor import EasyLightColorSensor

# import GoPiGo modules:
import easysensors
from easygopigo3 import EasyGoPiGo3
import time
easyGPG = EasyGoPiGo3()
easyGPG.reset_all()
easyGPG.reset_encoders()                                                                           
print('GoPiGo Initialized')   



# start the timer
start = time.time()

my_lcs = EasyLightColorSensor(led_state = True) # initialize sensor
print('Sensor initialized')

colors = ['red', 'green', 'blue', 'yellow']
num = random.randint(0,3)


while time.time():
    in_color = my_lcs.safe_raw_colors() # get raw data reading as a tuple (R,G,B,A)
    color_string = my_lcs.guess_color_hsv(in_color) # ask the library to guess the color
    print(color_string[0])
    requests.get('http://10.247.78.45:5000/lock')
    if color_string[0] == 'blue': #colors[num]: #random color emailed 
        print('boo')
        requests.get('http://10.247.78.45:5000/open')
        
    
    time.sleep(.05)
# Out:
# GoPiGo Initialized
# Sensor initialized
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# black
# ...

# %%
import random
num = random.randint(0,3)
print(num)
# Out:
# 1
